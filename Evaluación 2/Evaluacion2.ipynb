# %%
# Empezamos importando las bibliotecas que usaremos para la segunda evaluacion 
import numpy as np
import scipy.linalg as la
from scipy import integrate, linalg
import matplotlib.pyplot as plt
from scipy.integrate import odeint, solve_ivp
from mpl_toolkits import mplot3d

# %% [markdown]
# La ecuación diferencial del oscilador amortiguado es
#
# $$\begin{equation*}
# \frac{d^2 x}{d t^2} + 2 \zeta \omega_n \frac{dx}{dt}+\omega_n^2 x = \frac{1}{m } F_0 \sin(\omega t)
# \end{equation*}$$
# donde $\omega_n$ es la frecuencia angular natural del oscilador de masa $m$ y constante $k$ del resorte dado por la relación
#
# $$\begin{equation*}
# \omega_n = \sqrt{\frac{k}{m}}
# \end{equation*}$$
# y $\zeta$ es la tasa de amortiguamiento dado por la expresión
#
# $$\begin{equation*}
# \zeta = \frac{c}{2 \sqrt{mk}}
# \end{equation*}$$
# siendo $c$ un coeficiente de viscosidad por el movimiento del oscilador a través del aire.
#
# El lado derecho de la ecuación diferencial, es un término de forzamiento tipo sinoidal de amplitud $F_0$ y frecuencia de forzamiento $\omega$ ($\omega \neq \omega_n$).
#
# El valor del coeficiente $\zeta$, determinará el tipo de movimiento del oscilador:
#
# Movimiento sobreamortiguado ($\zeta &gt; 1$). El sistema decae exponencialmente al estado estacionario sin oscilar.
# Críticamente amortiguado ($\zeta = 1$).
# Movimiento subamortiguado ($\zeta &lt; 1$). Movimiento periódico que decae exponencialmente.
# Movimiento sin amortiguamiento ($\zeta = 0$). Movimiento periódico regular.

# %% [markdown]
# Problema1.
#
# Resuelva numéricamente primero el caso de un oscilador amortiguado caso sin forzamiento ($\zeta \neq 0, F_0=0$).
#
# Suponga que: $m=1, k=9, x(0) &lt; 0, x'(0) = 0$.
#
# Reproduzca una gráfica similar para los distintos casos de amortiguamiento $\zeta$:
#
# ![image.png](data:image/png;base64,...)

# %%
# Empezamos con la definicion de la funcion que utilizaremos para este caso el oscilador 
def pendulo(y,t,Omega_ag ,zeta,m,f0,omega):
  pos, vel = y
  # Definimos todas las variables con las cuales vamos a trabajar
  dydt = [vel, f0*np.sin(omega*t)/m - 2.0*zeta*omega_c*vel-omega_c**2*pos]
  return dydt


# Comenzamos definiendo algunas constantes que ocuparemos 
Omega_ag = np.sqrt(k/m)
m = 1
k = 9
f0 = 0
# Definmos la omega con un valor de 0 
omega = 0

# A continuacion los valores de z que nos interesan

# Para Zeta 1
zt1 = 0

# Para Zeta

Zta = 0.1

# Para zeta 2 
zt2 = 0.2

# Para Zeta 3 
zt3 = 0.4

# Para Zeta 4
zt4 = 0.7

# Para Zeta 5
zt5 = 1

# Para Zeta 6 
zt6 = 2


# Definimos la variable t 
t = np.linspace(0,12.56,550)

# Definimos el y0 o en una instancia inicial
y0 = [-1.0,0.0]

# Calculamos las soluciones respectivas para cada zeta
# Primero para la Solucion 1 
sol1 = odeint(pendulo, y0, t, args=(Omega_ag, zt1, m, f0, omega))

# Solucion para Zta = 0.1

sol = odeint(pendulo, y0, t, args=(Omega_ag, Zta, m, f0, omega))

# Solucion 2 
sol2 = odeint(pendulo, y0, t, args=(Omega_ag, zt2, m, f0, omega))

# Solucion 3
sol3 = odeint(pendulo, y0, t, args=(Omega_ag, zt3, m, f0, omega))

# Solucion 4
sol4 = odeint(pendulo, y0, t, args=(Omega_ag, zt4, m, f0, omega))

# Solucion 5
sol5 = odeint(pendulo, y0, t, args=(Omega_ag, zt5, m, f0, omega))

# Solucion 6
sol6 = odeint(pendulo, y0, t, args=(Omega_ag, zt6, m, f0, omega))


# Graficamos la primera solucion sol1
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 0")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()


#Primero para la solucion 1 
plt.plot(t, sol1[:, 0], label=" zeta = 0", color = "red")

plt.legend(loc="best")
plt.show()

# %%
# Graficamos la solucion de Zta = 0.1
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 0.1")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()


#Primero para la solucion 1 
plt.plot(t, sol[:, 0], label="zeta = 0.1", color = "purple")

plt.legend(loc="best")
plt.show()

# %%
# Graficamos la segunda solucion sol2
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 0.2 ")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()
#Segundo para la solucion 2
plt.plot(t, sol2[:, 0], label="zeta = 0.2", color = "g")

plt.legend(loc="best")
plt.show()

# %%
# Graficamos la Tercera solucion sol3
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 0.4")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

# Tercero para la solucion 3
plt.plot(t, sol3[:, 0], label="zeta = 0.4", color = "b")


plt.legend(loc="best")
plt.show()

# %%
# Graficamos la Cuarta solucion sol4
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 0.7")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

# Cuarto para la solucion 4
plt.plot(t, sol4[:, 0], label="zeta = 0.7", color = "y")

plt.legend(loc="best")
plt.show()

# %%
# Graficamos la Quinta solucion sol5
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 1")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

# Quinto para la solucion 5
plt.plot(t, sol5[:, 0], label="zeta = 1", color = "violet")

plt.legend(loc="best")
plt.show()

# %%
# Graficamos la Sexta solucion sol6
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador para el caso donde Zta = 2")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

# Sexto para la solucion 6
plt.plot(t, sol6[:, 0], label="zeta = 2", color = "orange")


plt.legend(loc="best")
plt.show()

# %%
#Ahora juntamos las graficas 
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador juntando todas las graficas")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

# Ahora graficamos las soluciones
plt.plot(t, sol1[:, 0], label = "zeta = 0", color = "red")
plt.plot(t, sol[:, 0], label = "zeta = 0.1", color = "purple")
plt.plot(t, sol2[:, 0], label = "zeta = 0.2", color = "g")
plt.plot(t, sol3[:, 0], label = "zeta = 0.4", color = "b")
plt.plot(t, sol4[:, 0], label = "zeta = 0.7", color = "y")
plt.plot(t, sol5[:, 0], label = "zeta = 1", color = "violet")
plt.plot(t, sol6[:, 0], label = "zeta = 2", color = "orange")


plt.legend(loc="best")
plt.show()

# %% [markdown]
# Problema 2.
#
# Resuelva numéricamente el caso de un oscilador forzado sin amortiguamiento ($\zeta = 0, F_0 \neq 0$).
#
# Suponga que: $F_0=1, m=1, k=9, x(0) = 0, x'(0) = 0$.
#
# Reproduzca una gráfica similar para los siguientes casos donde la frecuencia de forzamiento es: $\omega = 3, 3.1, 3.3, 3.5$
#
# ![image.png](data:image/png;base64,...)

# %%
# Empezamos definiendo las constantes con las cuales trabajaremos 
# Constante para Zeta = 0
zta = 0

# Funcion f0 = 1
f0 = 1

# Constante para m = 1 
m = 1

# Constante de K = 9
k = 9

# Definimos una omega con la cual trabajaremos 
Omega_ag = np.sqrt(9/1)

# Estudiaremos diferentes valores para omega, empezando con w = 3 hasta llegar a w = 3.5

# Caso donde omega es 3
w1 = 3

# Segundo caso donde omega es 3.1
w2 = 3.1

# tercer caso donde omega es 3.3
w3 = 3.3

# Cuarto caso donde omega es 3.5 
w4 = 3.5

# Agregamos las condiciones iniciales del trabajo
y0 = [0.0,0.]


# Definimos el tiempo de integracion 
t = np.linspace(0,150,1500)

# Calculamos las diferentes soluciones 
sol1 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w1))
sol2 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w2))
sol3 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w3))
sol4 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w4))

# Empezamos Graficando el primer caso donde w = 3 
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador con w = 3")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

plt.plot(t, sol1[:, 0], label= " omega = 3 ", color = "red")

plt.legend(loc="best")
plt.show()

# %%
# Graficamos el segundo caso donde w = 3.1
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador con w = 3.1")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()


plt.plot(t, sol2[:, 0], label=" omega = 3.1", color = "purple")
plt.legend(loc="best")
plt.show()

# %%
# Graficamos el tercer caso donde omega es 3.3 
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador con w = 3.3")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

plt.plot(t, sol3[:, 0], label=" omega = 3.3 ", color = "g")
plt.legend(loc="best")
plt.show()

# %%
# Graficamos el caso donde omega es 3.5

plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador con w = 3.5")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()


plt.plot(t, sol4[:, 0], label=" omega = 3.5 ")

plt.legend(loc="best")
plt.show()

# %%
# Ahora graficaremos todas en una misma 
plt.figure(figsize=(10,5))
plt.title("Posición contra tiempo para el oscilador con w = 3")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()

plt.plot(t, sol1[:, 0], label= " omega = 3 ", color = "red")
plt.plot(t, sol2[:, 0], label=" omega = 3.1", color = "purple")
plt.plot(t, sol3[:, 0], label=" omega = 3.3 ", color = "g")
plt.plot(t, sol4[:, 0], label=" omega = 3.5 ")


plt.legend(loc="best")
plt.show()

# %% [markdown]
# Problema 3.
#
# Ahora resolvemos el caso completo de un oscilador amortiguado y forzado con una fuerza sinoidal ($\zeta \neq 0, F_0 \neq 0$)
#
# Suponga un coeficiente de amortiguamiento $\zeta =0.1$.
#
# Tome los mismos valores del problema anterior: $F=1, m=1, k=9, x(0) = 0, x'(0) = 0$.
#
# Reproduzca una gráfica en el plano fase ($x,x'$), para las frecuencias de forzamiento: $\omega = 3, 3.1, 3.3, 3.5$, que muestre qué sucede con las soluciones del oscilador forzado en el caso amortiguado.

# %%
# Comenzamos definiendo las constantes con las cuales trabajaremos 

# La constante de k = 9 
k = 9

# Empezamos con el valor de Zeta = 1 
zta = 0.1

# La funcion f0 = 1 
f0 = 1

# La constante m = 1 
m = 1

# Definimos el valor de omega 
Omega_ag = np.sqrt(k/m)


# Definimos los omegas con los cuales trabajaremos 
# Primero para el caso donde omega = 3
w1 = 3

# Segundo caso donde omega es 3.1
w2 = 3.1

# Terccer caso donde omega es 3.3
w3 = 3.3

# Cuarto caso donde omega es 3.5
w4 = 3.5

#  Definimos las condiciones iniciales
y0 = [0.,0.]


# Definimos el tiempo de integracion 
t = np.linspace(0,70,1500)

# Calculamos las soluciones 
sol1 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w1))
sol2 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w2))
sol3 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w3))
sol4 = odeint(pendulo, y0, t, args=(Omega_ag, zta, m, f0, w4))

# Empezamos las graficas de cada caso 
# primero para el caso donde w = 3
plt.figure(figsize=(5,5))
plt.plot(sol1[:,1], sol1[:, 0], label="w = 3",color = "red")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.suptitle("Velocidad contra posición del caso donde w = 3", color = "red")
plt.show()

# %%
# Continuamos graficando ahora el caso donde w2= 3.1
plt.figure(figsize=(5,5))
plt.plot(sol2[:,1], sol2[:, 0], label=" w = 3.1", color = "purple")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.suptitle("Velocidad contra posición del caso donde w = 3.1")
plt.show()

# %%
# Continuamos graficando ahora el caso donde w3= 3.3
plt.figure(figsize=(5,5))
plt.plot(sol3[:,1], sol3[:, 0], label="w = 3.3", color = "g")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.suptitle("Velocidad contra posición del caso donde w = 3.3")
plt.show()

# %%
# Continuamos graficando ahora el caso donde w4= 3.5
plt.figure(figsize=(5,5))
plt.plot(sol4[:,1], sol4[:, 0], label="w = 3.5", color = "b")
plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.suptitle("Velocidad contra posición del caso donde w = 3.5")
plt.show()

# %%
# Ahora graficaremos todas en una misma para ver su resultado
plt.figure(figsize=(5,5))
plt.plot(sol1[:,1], sol1[:, 0], label="w = 3",color = "red")
plt.plot(sol2[:,1], sol2[:, 0], label=" w = 3.1", color = "purple")
plt.plot(sol3[:,1], sol3[:, 0], label="w = 3.3", color = "g")
plt.plot(sol4[:,1], sol4[:, 0], label="w = 3.5", color = "b")

plt.legend(loc="best")
plt.ylabel("v(t)")
plt.xlabel("x(t)")

plt.suptitle("Velocidad contra posición del caso donde estan todos", color = "purple")
plt.show()
