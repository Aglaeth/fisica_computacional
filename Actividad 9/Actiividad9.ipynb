# %%
#Empezamos importando las bibliotecas que vamos a utilizar 
import numpy as np
import scipy.linalg as la
from numpy.linalg import matrix_power as mpow
import matplotlib.pyplot as plt
from scipy.integrate import odeint, solve_ivp
from mpl_toolkits import mplot3d
from scipy import integrate, linalg
import pylab as plt

# %matplotlib inline

# %%
# Empezamos definiendo los valos para M 
def Valores( M ):
    '''
    Parámetros
    ----------
    M : Matriz a la que se le va sacar los diferentes valores
    
    Regresa
    -------
    Los Eigenvalores
    EL Delta
    La Traza
    El determinante
    
    '''
    eigvals, eigvecs = la.eig(M)
    tr = np.trace(M)
    det = la.det(M)
    Delta = (tr)**2 - (4*det)
    print("Eigenvectores", eigvecs)
    print()
    print('Eigenvalores:', eigvals)
    print()
    print("Traza de A1:", tr) 
    print()
    print("Determinante de A1:", det)
    print()
    print("Delta de A1:", Delta)
    print()

# %% [markdown]
# Ejercicios.
#
# Por favor grafique en el espacio fase una familia de soluciones y determine el tipo de punto crítico de cada uno de los siguientes sistemas de ecuaciones.
#
# Ejercicio 1.
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Declaramos la matriz para la ecuacion 1 
A1 =np.array([[0,1],
              [-1,0]])

# %%
# Imprimimos los valores para la matriz de la ecuacion 1 
Valores( A1 )
# Out:
# Eigenvectores [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]
#
# Eigenvalores: [0.+1.j 0.-1.j]
#
# Traza de A1: 0
#
# Determinante de A1: 1.0
#
# Delta de A1: -4.0

# %%
# Continuamos con la solucion de la ecuacion diferencial 1 

# Tendremos que definir cuale son los valores del vector x

def dX_dt(X, t=1):
    return np.array([ X[1] , - X[0]])

# Identificamos los puntos criticos del sistema 
X_f0 = np.array([     0. ,     0.])
all(dX_dt(X_f0) == np.zeros(2) )

# Iniciamos con la solucion numerica 

t = np.linspace( 0, 2*np.pi, 51 )
X0 = np.array([1, 1])                    

X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y = X.T

# %%
#Imprimimos la solcion x(t)

f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)', color = "g");

plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Soluciones x(t)');
plt.show();

# %%
#Imprimimos la solucion y(t)

f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, y  , 'b-', label='y(t)', color = "purple");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Soluciones y(t)');
plt.show();

# %%
#Ahora imprimimos las dos soluciones juntas

f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)', color ="g");
plt.plot(t, y  , 'b-', label='y(t)', color = "Purple");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
#Encontramos la solucion en el plano de fase

plt.plot(x, y, color ='g')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Ejercicio 2.
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &amp; = &amp; y  \\
# \frac{d y}{dt } &amp; = &amp;  x  \\
# \end{eqnarray*}$$

# %%
#Empezamos definiendo cuales son la matriz de la ecuacion 2 
A2 =np.array([[0,1],
              [1,0]])

# %%
#Imprimimos los valores para A2 
Valores( A2 )
# Out:
# Eigenvectores [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
#
# Eigenvalores: [ 1.+0.j -1.+0.j]
#
# Traza de A1: 0
#
# Determinante de A1: -1.0
#
# Delta de A1: 4.0

# %%
# Continuamos con la solucion de la ecuacion diferencial 2 
# Definiremos un vector x 

def dX_dt(X, t=1):
    return np.array([ X[1] , X[0]])

# Identificamos cuales son los puntos criticos del sistema 
X_f0 = np.array([     0. ,     0.])
all(dX_dt(X_f0) == np.zeros(2) )

# Encontraremos una solucion numerica 

t = np.linspace( 0, 2*np.pi, 51 )
X0 = np.array([1, 1])                    
 # tendremos condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y = X.T

# %%
#Imprimimos la primera solucion 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion x(t)');
plt.show();

# %%
#Ahora imprimimos la senguda solucion y(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, y  , 'b-', label='y(t)');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion y(t)');
plt.show();

# %%
# Imprimiremos la figura con ambas soluciones 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.plot(t, y  , 'b-', label='y(t)');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
# La solucion en el plano 

plt.plot(x, y, color ='purple')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Ejercicio 3.
#
# $$\begin{eqnarray*}
# \frac{d^2 x}{d t^2} + \omega_0^2 x &amp; = &amp; 0, \ \omega_0 &gt; 0  \\
# \end{eqnarray*}$$

# %%
# Tendremos que tener algunas consieraciones las cuales seran Como W > 0 

# Definiremos w = 1 
w = 1

# %%
# Definimos la matriz 3 
A3 =np.array([[1,0],
              [0,-w**2]])

# %%
# Imprimimos los valores de A3 
Valores( A3 )
# Out:
# Eigenvectores [[1. 0.]
#  [0. 1.]]
#
# Eigenvalores: [ 1.+0.j -1.+0.j]
#
# Traza de A1: 0
#
# Determinante de A1: -1.0
#
# Delta de A1: 4.0

# %%
# Tendremos la solucion de la ecuacion diferncial del ejercicio 3 
# Definiremos unos vectores x 

def dX_dt(X, t=1):
    return np.array([ X[0] , - X[1]**2])

# Tendremos puntos critico del sistema 
X_f0 = np.array([     0. ,     0.])
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# True

# %%
# Comenzamos con una solucion numerica del problema 3

t = np.linspace( 0, 2*np.pi, 51 )
X0 = np.array([1, 1])                    
# Agregamos las Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y = X.T

# %%
#Empezamos imprimiendo la solucion x(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion x(t)');
plt.show();

# %%
#Imprimimos la segunda solucion 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, y  , 'b-', label='y(t)', color = "g");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion y(t)');
plt.show();

# %%
# Vamos a imprimir ambas solucioes 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.plot(t, y  , 'b-', label='y(t)');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
# Encontramos la solucion plano 

plt.plot(x, y, color = 'g')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Ejercicio 4.
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &amp; = &amp; -2 x  \\
# \frac{d y}{dt } &amp; = &amp;  2 z  \\
# \frac{d z}{dt } &amp; = &amp;  - 2 y  \\
# \end{eqnarray*}$$

# %%
#Empezamos con la declaracion de la matriz del problema 4 
A4 =np.array([[  0, 2],
              [ -2, 0]])

# %%
#Imprimimos los valores para el problema 4 
Valores( A4 )
# Out:
# Eigenvectores [[0.        -0.70710678j 0.        +0.70710678j]
#  [0.70710678+0.j         0.70710678-0.j        ]]
#
# Eigenvalores: [0.+2.j 0.-2.j]
#
# Traza de A1: 0
#
# Determinante de A1: 4.0
#
# Delta de A1: -16.0

# %%
# Continuamos con la solucion del problema 4 
# Definiremos las condiciones 

t = np.linspace( -5, 50, 1000 )
 
c1 = np.linspace( -0.5 ,    4 , 5 )
c2 = np.linspace(    5 , -0.2 , 5 )
c3 = np.linspace(  -10 ,   11 , 5 )

# Definimos cual sera la funcion 

def F4( t,c1, c2, c3 ):
  r=[c1*( np.exp(-2*t)), c2*np.cos( 2*t ) + c3*np.sin( 2*t )  ,
     -c2*np.sin( 2*t ) + c3*np.cos( 2*t )  ]
  return r

# %%
# Vmos a imprimir la solcion de la grafica 4 
plt.figure(figsize = ( 12, 10 ))

# Le daremos un efecto en 3d
ax = plt.axes( projection= "3d" )

for c,d,e in zip(c1,c2,c3):
  v = F4(t,c,d,e)
  s = np.array(v)
  ax.plot3D(s[0,:],s[1,:],s[2,:])
 
plt.xlabel("x(t)")
plt.ylabel("y(t)")
ax.set_zlabel("z(t)")
plt.title("SOLUCION DEL SISTEMA")
plt.grid()
plt.show()

# %% [markdown]
# Ejercicio 5.
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &amp; = &amp; - x + z  \\
# \frac{d y}{dt } &amp; = &amp;  3 y  \\
# \frac{d z}{dt } &amp; = &amp;  - x - z \\
# \end{eqnarray*}$$

# %%
#Declaramos la matriz del problema 5 
A5 =np.array([[  -1 , 1  ],
              [  -1 , -1 ]])

# %%
# Imprimimos el valor numerico de ejercicio 5 
Valores( A5 )
# Out:
# Eigenvectores [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]
#
# Eigenvalores: [-1.+1.j -1.-1.j]
#
# Traza de A1: -2
#
# Determinante de A1: 2.0
#
# Delta de A1: -4.0

# %%
# Tenremos la solucion de la ecuacion diferencial 5 

# Definimos las condiciones 

t = np.linspace( -5, 50, 1000 )
 
c1 = np.linspace( -0.5 ,    4 , 5 )
c2 = np.linspace(    5 , -0.2 , 5 )
c3 = np.linspace(  -10 ,   11 , 5 )

# %%
# Declaramos la funcion de fase del problema 5

def F4( t,c1, c2, c3 ):
  r=[(c2*np.cos( 1*t ) + c3*np.sin( 1*t ))*np.exp(-t)  ,c1*( np.exp(3*t)),
     (-c2*np.sin( 1*t ) + c3*np.cos( 1*t ))*np.exp(-t)  ]
  return r

# %%
# Graficamos el problema 5
plt.figure(figsize = ( 11, 9 ))
ax = plt.axes( projection= "3d" )
for c,d,e in zip(c1,c2,c3):
  v = F4(t,c,d,e)
  s = np.array(v)
  ax.plot3D(s[0,:],s[1,:],s[2,:])
 
plt.xlabel("x(t)")
plt.ylabel("y(t)")
ax.set_zlabel("z(t)")
plt.title("Solucion ")
plt.grid()
plt.show()

# %% [markdown]
# Ejercicio 6:
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &amp; = &amp; - x  \\
# \frac{d y}{dt } &amp; = &amp;  x + 2 y  \\
# x(0) = 0, &amp; &amp; y(0) = 3
# \end{eqnarray*}$$

# %%
# Tendremos que declarar la matriz del problema 6
A6 =np.array([[  -1 , 0  ],
              [   1 , 2  ]])

# %%
# Vamos a imprimir los valores del problema 6
Valores(A6)
# Out:
# Eigenvectores [[ 0.          0.9486833 ]
#  [ 1.         -0.31622777]]
#
# Eigenvalores: [ 2.+0.j -1.+0.j]
#
# Traza de A1: 1
#
# Determinante de A1: -2.0
#
# Delta de A1: 9.0

# %%
# Tendremos las soluciones de la ecuacion diferencial 6 

# Vamos a definir un vector x 

def dX_dt(X, t=1):
    return np.array([ -X[0] , X[0] + 2*X[1]])

# %%
# Identificamos los puntos criticos del sistema 
X_f1 = np.array([     1. ,  -1/2.])
X_f0 = np.array([     0. ,     0.])
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# True

# %%
# Tendremos la solucion numerica para el problema 6 

t = np.linspace(1, 5,  500)              # Rango de tiempo de integración
X0 = np.array([0, 3])                     # Condiciones iniciales
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y = X.T

# %%
#Imprimimos la primera solucion 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion x(t)');
plt.show();

# %%
#Imprimimos la segunda solucion 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, y  , 'b-', label='y(t)', color = "g");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Solucion y(t)');
plt.show();

# %%
#Imprimimos ambas soluciones 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)');
plt.plot(t, y  , 'b-', label='y(t)', color = "purple");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
# Tendremos la solucion del plano de fase 
plt.plot(x, y, color= 'purple')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Ejercicio 7:
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &amp; = &amp; 2 x + y  \\
# \frac{d y}{dt } &amp; = &amp;  x +  y  \\
# x(1) = 1, &amp; &amp; y(1) = 1
# \end{eqnarray*}$$

# %%
# Definimos la matriz del problema 7
A7 =np.array([[  2 , 1  ],
              [  1 , 1  ]])

# %%
# Vmos a imprimir los valores 
Valores(A7)
# Out:
# Eigenvectores [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]
#
# Eigenvalores: [2.61803399+0.j 0.38196601+0.j]
#
# Traza de A1: 3
#
# Determinante de A1: 1.0
#
# Delta de A1: 5.0

# %%
# Tendremos la solucion de la ecuacion diferencial 7 

# Tendremos un vector x 

def dX_dt(X, t=1):
    return np.array([ 2*X[0]+X[1] , X[0] + X[1]])

# %%
# Identificamos los puntos criticos del sistema 
X_f0 = np.array([     0. ,     0.])
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# True

# %%
# Encontramos una solucion numerica 

t = np.linspace(1, 5,  700)             
X0 = np.array([1, 1])                  
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y = X.T

# %%
# Vamos a imprimir la solucion x(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)', color = "purple");
plt.grid();
plt.ylim(0, 10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion x(t)');
plt.show();

# %%
# Imprimimos la sengunda solucion y(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)', color = "g");
plt.grid();
plt.ylim(0, 10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion y(t)');
plt.show();

# %%
# Imprimimos ambas soluciones 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)' ,color = "purple");
plt.plot(t, y  , 'b-', label='y(t)', color = "r");
plt.grid();
plt.ylim(0, 10)
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
# Encontramos la solucion de fase 

plt.plot(x, y, color ='r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Ejercicio 8:
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &; = &; A x  \\
# x(0) &; = &; (0,3) \\
# A &; = &; \begin{bmatrix}
# 0 &; 3 \\
# 1 &; -2 \\
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Definimos la matrix para el problema 8 

A8 =np.array([[  0 ,  3  ],
              [  1 , -2  ]])

# %%
# Vamos a imprimir los valores para esa matrix
Valores(A8)
# Out:
# Eigenvectores [[ 0.9486833  -0.70710678]
#  [ 0.31622777  0.70710678]]
#
# Eigenvalores: [ 1.+0.j -3.+0.j]
#
# Traza de A1: -2
#
# Determinante de A1: -3.0
#
# Delta de A1: 16.0

# %%
# Tendremos la ecuacion diferencial para el problema 8

# Definimos el vector x 

def dX_dt(X, t=1):
    return np.array([3*X[1] , X[0] - 2*X[1]])

# %%
# Identificamos los puntos criticos 
X_f0 = np.array([     0. ,     0.])
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# True

# %%
# Tendremos una solucion numerica 

t = np.linspace(1, 5,  700)              
X0 = np.array([0, 3])                     
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y = X.T

# %%
#Imrpimimos la primera solucion x(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)', color = "purple");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion x(t)');
plt.show();

# %%
#Imprimimos la segunda solucion 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, y  , 'b-', label='y(t)', color = "r");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion y(t)');
plt.show();

# %%
# Vamos a imprimir ambas soluciones 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
plt.plot(t, x, 'r-', label='x(t)', color = "purple");
plt.plot(t, y  , 'b-', label='y(t)', color = "r");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t)');
plt.show();

# %%
# Encontramos la solucion del plano 
plt.plot(x, y, color ='purple')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# Ejercicio 9:
#
# $$\begin{eqnarray*}
# \frac{d x}{d t} &; = &; A x  \\
# x(0) &; = &; (0,-b,b) \\
# A &; = &; \begin{bmatrix}
# 2 &; 0 &; 0 \\
# 0 &; -1 &; 0 \\
# 0 &; 2 &; -3 \\
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
#Declaramos la matriz del problema 9
A9 =np.array([[  2 ,  0  ,  0 ],
              [  0 , -1  ,  0 ],
              [  0 ,  2  , -3 ]])

# %%
# Imprimimos los valores del problema 9
Valores(A9)
# Out:
# Eigenvectores [[1.         0.         0.        ]
#  [0.         0.         0.70710678]
#  [0.         1.         0.70710678]]
#
# Eigenvalores: [ 2.+0.j -3.+0.j -1.+0.j]
#
# Traza de A1: -2
#
# Determinante de A1: 6.0
#
# Delta de A1: -20.0

# %%
# Comenzamos con la solucion del ejercicio 9

def dX_dt(X, t=1):
    return np.array([2*X[0] ,-1*X[1] , 2*X[1] - 3*X[2]])

# %%
# Identificamos los puntos criticos 
X_f0 = np.array([     0. ,     0.,    0.])
all(dX_dt(X_f0) == np.zeros(3) )
# Out:
# True

# %%
# Tendremos la solucion numerica 

t = np.linspace(1, 5,  500)

# %%
# Asignaremos el valor de b arbitrariamente 
b=1
X0 = np.array([0, -b, b])                 

X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']

x, y,  z = X.T

# %%
# Comenzamos imprimiendo la solucion x(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
ax = plt.axes( projection= "3d" )
ax.plot3D(t, x, label='x(t)', color ="purple");
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion x(t)');
plt.show();

# %%
#Ahora vamos a imprimir la segunda solucion 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
ax = plt.axes( projection= "3d" )
ax.plot3D(t, y  , label='y(t)', color ="g")
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion y(t)');
plt.show();

# %%
# Tendremos la solucion de z(t)
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
ax = plt.axes( projection= "3d" )
ax.plot3D(t, y  , label='z(t)', color ="r")
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Solucion');
plt.title('Solucion z(t)');
plt.show();

# %%
# Vamos a imprimir las soluciones 
f1 = plt.figure();
plt.figure(figsize=(10, 5)); 
ax = plt.axes( projection= "3d" )
ax.plot3D(t, x, label='x(t)')
ax.plot3D(t, y  ,label='y(t)')
ax.plot3D(t, y  , label='z(t)')
plt.grid();
plt.legend(loc='best');
plt.xlabel('tiempo');
plt.ylabel('Soluciones');
plt.title('Soluciones x(t), y(t), z(t)');
plt.show();

# %% [markdown]
# Ejercicio 10:
#
# Se tiene el siguiente sistema de resortes acoplados con dos masas.
#
# ![image.png](data:image/png;base64,...)
#
# El sistema esta sujeto del primer resorte de la izquierda. Cuando el sistema se deja en reposo, las longitudes de los resortes son $L_1$ y $L_2$.
#
# Las ecuaciones de movimiento estan dadas por las siguientes ecuaciones diferenciales acopladas:
#
# $$\begin{eqnarray*}
# m_1 x_1^{''} + b_1 x_1^{'}+k_1 (x_1-L_1)-k_2(x_2-x_1-L_2) &; = &; 0 \\
# m_2 x_2^{''} + b_2 x_2^{'}+k_2(x_2-x_1-L_2) &; = &; 0 \\
# \end{eqnarray*}$$
# Encuentre las soluciones como funciones de $t$ y grafíquelas, así como las trayectorias en el espacio fase.
#
# Suponga que $L_1=L_2=1$ y que las masas son iguales $m_1=m_2=1$.

# %% [markdown]
# 10.1) Encuentre los eigenvalores del sistema y diga como son las soluciones.

# %%
# Definimos condiciones iniciales 

b1 = 0.5 
k1 = 6
m1 = 1

b2 = 0.5 
k2 = 4
m2 = 1

# %%
# Vamos a definir el arreglo 
A = np.array( [ [ 0, 1, 0, 0 ],
                [ -( k2 + k1 )/m1, -b1/m1, k2/m1, 0 ],
                [ 0, 0, 0, 1 ],
                [ k2/m2, 0, -k2/m2, -b2/m2 ] ] )

# %%
#Imprimimos los resultados
print( "b1 = ", b1 )
print( "k1 = ", k1 )
print( "m1 = ", m1 )
print( " " )
# Out:
# b1 =  0.5
# k1 =  6
# m1 =  1

# %%
print( "b2 = ", b2 )
print( "k2 = ", k2 )
print( "m2 = ", m2 )
print( " " )
# Out:
# b2 =  0.5
# k2 =  4
# m2 =  1

# %%
print('La matriz A es:')
print(A)
print()
# Out:
# La matriz A es:
# [[  0.    1.    0.    0. ]
#  [-10.   -0.5   4.    0. ]
#  [  0.    0.    0.    1. ]
#  [  4.    0.   -4.   -0.5]]

# %%
eigvals, eigvecs = la.eig( A )
print( 'Los eigenvalores son:')
print( eigvals )
print()
print( 'Los eigenvectores son:' )
print( eigvecs )
# Out:
# Los eigenvalores son:
# [-0.25+3.45506874j -0.25-3.45506874j -0.25+1.39194109j -0.25-1.39194109j]
#
# Los eigenvectores son:
# [[-0.01790287-2.47422612e-01j -0.01790287+2.47422612e-01j
#   -0.04564355-2.54132511e-01j -0.04564355+2.54132511e-01j]
#  [ 0.85933785+0.00000000e+00j  0.85933785-0.00000000e+00j
#    0.36514837+6.93889390e-17j  0.36514837-6.93889390e-17j]
#  [ 0.00895144+1.23711306e-01j  0.00895144-1.23711306e-01j
#   -0.09128709-5.08265023e-01j -0.09128709+5.08265023e-01j]
#  [-0.42966892-8.32667268e-17j -0.42966892+8.32667268e-17j
#    0.73029674+0.00000000e+00j  0.73029674-0.00000000e+00j]]

# %% [markdown]
# 10.2) Caso sin fricción. $b_1=b_2=0$, $k_1=6$, $k_2=4$, condiciones iniciales $(x_1(0), x_1^{'}(0), x_2(0), x_2^{'}(0))=(1,0,4,0)$

# %%
# Definimos las condiciones iniciales 
b1 = 0
b2 = 0
k1 = 6
k2 = 4

# %%
# Definimos el arreglo X0
x0 = np.array([1,0,4,0])

# %%
#Definimos la matriz A
A = np.array([[0,0,1,0],[0,0,0,1],[-(k1+k2),k2,-b1,0],[k2,-k2,0,-b2]])

# %%
#Calculamos los eigenvalores de la matriz
lam1, lam2, lam3, lam4 = linalg.eigvals(A)

# %%
#Imprimimos los eigenvalores
print('Eigenvalores:')
print('λ1: ', lam1)
print('λ2: ', lam2)
print('λ3: ', lam3)
print('λ4: ', lam4)
# Out:
# Eigenvalores:
# λ1:  (-7.848128277522717e-18+3.4641016151377553j)
# λ2:  (-7.848128277522717e-18-3.4641016151377553j)
# λ3:  (3.5603703886533236e-17+1.4142135623730951j)
# λ4:  (3.5603703886533236e-17-1.4142135623730951j)

# %%
# Definimos el arreglo
def f10(x0, t, k1, k2, b1, b2):
  x1, x2, x3, x4 = x0
  dxdt=[x3, x4, -(k1+k2)*x1+k2*x2-b1*x3+k1-k2, k2*x1-k2*x2-b2*x4+k2]
  return dxdt
t=np.linspace(0,70,3000)
X=odeint(f10,x0,t,args=(k1, k2, b1, b2))

# %%
# Hacemos el grafico del problema 
plt.figure(figsize=(5,5))
plt.plot(X[:,0],X[:,1],color='purple')
plt.title('Espacio fase')
plt.xlabel('x1(t)')
plt.ylabel('x2(t)')
plt.grid()
plt.show()

# %%
# Ahora toca graficar las soluciones 
plt.figure(figsize=(13,9))
plt.plot(t,X[:,0],color='purple',label='x1(t)')
plt.plot(t,X[:,1],color='r',label='x2(t)')
plt.plot(t,X[:,2],color='g',label='x3(t)')
plt.plot(t,X[:,3],color='b',label='x4(t)')
plt.title('Soluciones del sistema')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt
from matplotlib import cm
Xf0 = np.array( [ 0.0, 0.0, 0.0, 0.0  ] ) # Puntos criticos del sistema 
                                          # Usando matriz aumentada de gauss
X0 = np.array( [ 1.0, 0.0, 4.0, 0.0 ] ) 
# Graficamos la familia de soluciones en el espacio fase para distintas condiciones iniciales

Vals = np.linspace( 1, 10, 1 ) # posición de X0 entre Xf0 y Xf1
Vcolors = plt.cm.cividis( np.linspace( 0.3, 1., len( Vals ) ) ) # colores para cada trayectoria
 
plt.figure( figsize = ( 12, 8 ) ); 

#-------------------------------------------------------------------------------

# grafica las trayectorias

def dXdt(X,t=0):
  return np.array( [ X[ 1 ], 
                     -( k2 + k1 )*X[ 0 ] - b1*X[ 1 ] + k2*X[ 2 ] ,  
                     X[ 3 ],   
                     -k2*X[ 2 ] + k2*X[ 0 ] ] )



for V, col in zip( Vals, Vcolors ):
    X0 = V * Xf0 # punto inicial
    X = odeint( dXdt, X0, t ) # Integración para cada condición inicial
    plt.plot( X[ :, 0 ], X[ :, 2 ], lw = 3.5*V, Color = col,
             label = "X0 = ( %.f, %.f )" % ( X0[ 0 ], X0[ 2 ] ) )
    
ymax = plt.ylim( ymin = 0 )[ 1 ] # get axis limits
xmax = plt.xlim( xmin = 0 )[ 1 ]

for V, col in zip( Vals, Vcolors ):
    X0 = V * Xf0 # punto inicial
    X = odeint( dXdt, X0, t )         
    # Integración para cada condición inicial
    plt.plot( X[ :,1 ], X[ :,3 ], lw =3.5*V, Color=col,
             label = "X0 = ( %.f, %.f )" % ( X0[ 1 ], X0[ 3 ] ) )

#-------------------------------------------------------------------------------

# Define una malla y calcula la pendiente (dirección) en cada punto

y2max = plt.ylim( ymin = 0 )[ 1 ]   
x2max = plt.xlim( xmin = 0 )[ 1 ] 
nb_points = 20

x = np.linspace( 0, xmax, nb_points )
y = np.linspace( 0, ymax, nb_points )
x2 = np.linspace( 0, x2max, nb_points )
y2 = np.linspace( 0, y2max, nb_points )

X1 ,Y1 = np.meshgrid( x, y )     
X2 ,Y2 = np.meshgrid( x2, y2 )                    # crea la malla
DX1, DY1, DX2, DY2 = dXdt( [ X1, Y1, X2, Y2 ] ) 
  # dX_df es una funcion # calcula la tasa de crecimiento
  # De 4 componentes necesito la de x1 y x2


M = ( np.hypot( DX1, DY1 ) ) # distancia euclideana 
M[ M == 0 ] = 1.             # Evita divisiones entre 0 
DX1 /= M                     # Normaliza el tamaño de cada flecha
DY1 /= M

#-------------------------------------------------------------------------------

# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento

plt.title( "Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)" )
Q = plt.quiver( X1, Y1, DX1, DY1, M, pivot = "mid", cmap=plt.cm.jet )
plt.xlabel( "X1" )
plt.ylabel( "X2" )
plt.legend( loc = "best" )
plt.grid()

plt.xlim( 0, xmax )
plt.ylim( 0, ymax )
plt.show()

# %% [markdown]
# 10.3) Igual que el caso anterior pero, con fricción: $b_1=0.1, b_2=0.2$

# %%
import numpy as np
from scipy import integrate, linalg
import pylab as plt
from matplotlib import cm

# Graficamos la familia de soluciones en el espacio fase para distintas condiciones iniciales

values  = np.linspace( 1, 10, 1 ) # posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis( np.linspace( 0.3, 1., len( values ) ) ) # colores para cada trayectoria
plt.figure(figsize=( 12, 8 ) ); 

#-------------------------------------------------------------------------------

# grafica las trayectorias

for v, col in zip( values, vcolors ):
    X0 = v * Xf0 # punto inicial
    X = integrate.odeint( dXdt, X0, t ) # Integración para cada condición inicial
    plt.plot( X[ :, 0 ], X[ :, 2 ], lw = 3.5*v, color = col,
             label = "X0 = (%.f, %.f)" % ( X0[ 0 ], X0[ 2 ] ) )
    
ymax = plt.ylim( ymin = 0 )[ 1 ] # get axis limits
xmax = plt.xlim( xmin = 0 )[ 1 ]

for v, col in zip( values, vcolors ):
    X0 = v * Xf0 # punto inicial
    X = integrate.odeint( dXdt, X0, t ) # Integración para cada condición inicial
    plt.plot( X[ :, 1 ], X[ :, 3 ], lw = 3.5*v, color = col,
             label = "X0 = (%.f, %.f)" % ( X0[ 1 ], X0[ 3 ]) )
    
    
# Define una malla y calcula la pendiente (dirección) en cada punto

y2max= plt.ylim( ymin = 0 )[ 1 ]   
x2max= plt.xlim( xmin = 0 )[ 1 ] 
nb_points = 20

x = np.linspace( 0, xmax, nb_points )
y = np.linspace( 0, ymax, nb_points )
x2 = np.linspace( 0, x2max, nb_points )
y2 = np.linspace( 0, y2max, nb_points )

X1 , Y1 = np.meshgrid( x, y )     
X2 , Y2 = np.meshgrid( x2, y2 )                # crea la malla
DX1, DY1, DX2, DY2 = dXdt( [ X1, Y1, X2, Y2 ]) 
# dX_df es una funcion                     # calcula la tasa de crecimiento
# De 4 componentes necesito la de x1 y x2

M = ( np.hypot( DX1, DY1 ) ) # distancia euclideana 
M[ M == 0] = 1.              # Evita divisiones entre 0 
DX1 /= M                     # Normaliza el tamaño de cada flecha
DY1 /= M

#-------------------------------------------------------------------------------

# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento

plt.title( "Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)" )
Q = plt.quiver( X1, Y1, DX1, DY1, M, pivot="mid", cmap = plt.cm.jet )
plt.xlabel( "X1" )
plt.ylabel( "X2" )
plt.legend( loc = "best" )
plt.grid()

plt.xlim( 0, xmax )
plt.ylim( 0, ymax )
plt.show()

# %%
#Definimos la misma función anterior 
def r(y,t,k1,k2,b1,b2):
  x1, x2, x3, x4 = y
  dxdt=[x3, x4, -(k1+k2)*x1+k2*x2-b1*x3+k1-k2, k2*x1-k2*x2-b2*x4+k2]
  return dxdt
# Agregamos las condiciones iniciales 
b1 = 0.1
b2 = 0.2
k1 = 6
k2 = 4
y_0=[1,4,0,0]

# %%
# Sacaremos los eigenvalores 
# Definimos el arreglo A 
A=np.array([[0,0,1,0],[0,0,0,1],[-(k1+k2),k2,-b1,0],[k2,-k2,0,b2]])
eigenval, eigenvec = la.eig(A)
print("Los eigenvalores son:",eigenval)
# Out:
# Los eigenvalores son: [-0.02012662+3.46155525j -0.02012662-3.46155525j  0.07012662+1.41349145j
#   0.07012662-1.41349145j]

# %%
#Los primeros eigenvalores se podrían considerar como cero, pero en este caso no lo consideraremos como cero 
t=np.linspace(0,50,1500)
y=odeint(r,y_0,t,args=(k1, k2, b1, b2))
#Gáfica del espacio fase 
plt.figure(figsize=(8,9))
plt.plot(y[0:,0],y[0:,1],color='purple')
plt.title('Espacio fase de la solución')
plt.xlabel('x1')
plt.ylabel('x2')
plt.grid()
plt.show()

# %%
# Ahora toca graficar el resto del sistema 
plt.figure(figsize=(13,8))
plt.plot(t,y[0:,0],label='x1(t)', color='r')
plt.plot(t,y[0:,1],label='x2(t)', color='purple')
plt.title('Grafica de las soluciones del sistema ')
plt.xlabel('$t$')
plt.ylabel('$y$')
plt.legend()
plt.grid()
plt.show()
